# %% [markdown]
# <a href="https://colab.research.google.com/github/bchanyoo/dakum/blob/main/datapreprocessing%2001.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # 데이터 전처리
# ## Scaling
# ##### Min-Max Scaling (값이 0~1 사이로 변경됨.)
# ##### Standard Scaling (z 정규화 이용)
# ## Sampling
# ## Dimensionality Reduction -> 차원 축소
# ## Categorical Variable to Numeric Variable

# %%
import numpy as np
import pandas as pd
import sklearn
import matplotlib.pyplot as plt #데이터 시각화때 사용.
import os
from os.path import join
import warnings 
warnings.filterwarnings('ignore')

# %% [markdown]
# 먼저 머신러닝의 대표적인 데이터셋 중 하나인 전복 데이터를 불러오겠습니다.
# 전복 데이터셋은 수컷, 암컷, 유아기 3개의 범주로 이루어진 범주형 변수와 길이, 직경, 높이, 무게 등 여러 수치형 변수로 이뤄져 있습니다.
# 데이터를 불러온 후 입력으로 사용할 변수들과 레이블로 사용할 성별 변수로 나누겠습니다.

# %%
abalone_path = join('sample_data', 'abalone.txt') 
column_path = join('sample_data', 'abalone_attributes.txt')
abalone_columns = list() #리스트 객체로 저장
for l in open(column_path):
  abalone_columns.append(l.strip()) #append로 리스트 객체에 하나씩 반복해서 추가. strip으로 개행문자(군더더기들)다 지우기.
#print(abalone_columns)

#Pandas를 이용해 abalone 데이터를 불러오기.
data = pd.read_csv(abalone_path,
                   header = None,
                   names = abalone_columns)#첫 행부터 데이터임을 표시해줘야 함. 첫행이 column화 되어있음.
data
# Out:
#      Sex  Length  Diameter  Height  Whole weight  Shucked weight  \
# 0      M   0.455     0.365   0.095        0.5140          0.2245
# 1      M   0.350     0.265   0.090        0.2255          0.0995
# 2      F   0.530     0.420   0.135        0.6770          0.2565
# 3      M   0.440     0.365   0.125        0.5160          0.2155
# 4      I   0.330     0.255   0.080        0.2050          0.0895
# ...   ..     ...       ...     ...           ...             ...
# 4172   F   0.565     0.450   0.165        0.8870          0.3700
# 4173   M   0.590     0.440   0.135        0.9660          0.4390
# 4174   M   0.600     0.475   0.205        1.1760          0.5255
# 4175   F   0.625     0.485   0.150        1.0945          0.5310
# 4176   M   0.710     0.555   0.195        1.9485          0.9455
#
#       Viscera weight  Shell weight  Rings
# 0             0.1010        0.1500     15
# 1             0.0485        0.0700      7
# 2             0.1415        0.2100      9
# ...

# %%
# head(), shape를 이용해서 데이터를 살펴보기.
data.head()
# Out:
#   Sex  Length  Diameter  Height  Whole weight  Shucked weight  Viscera weight  \
# 0   M   0.455     0.365   0.095        0.5140          0.2245          0.1010
# 1   M   0.350     0.265   0.090        0.2255          0.0995          0.0485
# 2   F   0.530     0.420   0.135        0.6770          0.2565          0.1415
# 3   M   0.440     0.365   0.125        0.5160          0.2155          0.1140
# 4   I   0.330     0.255   0.080        0.2050          0.0895          0.0395
#
#    Shell weight  Rings
# 0         0.150     15
# 1         0.070      7
# 2         0.210      9
# 3         0.155     10
# 4         0.055      7

# %%
data.shape
# Out:
# (4177, 9)

# %%
#label 데이터와 실제 데이터를 구분하기. 
#위에서는 성별이 label 데이터.
label = data['Sex'] #뒤에서 라벨을 쓰기 위해 미리 빼둠.
del data['Sex']
data.head()
# Out:
#    Length  Diameter  Height  Whole weight  Shucked weight  Viscera weight  \
# 0   0.455     0.365   0.095        0.5140          0.2245          0.1010
# 1   0.350     0.265   0.090        0.2255          0.0995          0.0485
# 2   0.530     0.420   0.135        0.6770          0.2565          0.1415
# 3   0.440     0.365   0.125        0.5160          0.2155          0.1140
# 4   0.330     0.255   0.080        0.2050          0.0895          0.0395
#
#    Shell weight  Rings
# 0         0.150     15
# 1         0.070      7
# 2         0.210      9
# 3         0.155     10
# 4         0.055      7

# %%
data.describe() #데이터 전체의 숫자 범위값
# Out:
#             Length     Diameter       Height  Whole weight  Shucked weight  \
# count  4177.000000  4177.000000  4177.000000   4177.000000     4177.000000
# mean      0.523992     0.407881     0.139516      0.828742        0.359367
# std       0.120093     0.099240     0.041827      0.490389        0.221963
# min       0.075000     0.055000     0.000000      0.002000        0.001000
# 25%       0.450000     0.350000     0.115000      0.441500        0.186000
# 50%       0.545000     0.425000     0.140000      0.799500        0.336000
# 75%       0.615000     0.480000     0.165000      1.153000        0.502000
# max       0.815000     0.650000     1.130000      2.825500        1.488000
#
#        Viscera weight  Shell weight        Rings
# count     4177.000000   4177.000000  4177.000000
# mean         0.180594      0.238831     9.933684
# std          0.109614      0.139203     3.224169
# min          0.000500      0.001500     1.000000
# ...

# %%
#자료형 확인
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4177 entries, 0 to 4176
# Data columns (total 8 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   Length          4177 non-null   float64
#  1   Diameter        4177 non-null   float64
#  2   Height          4177 non-null   float64
#  3   Whole weight    4177 non-null   float64
#  4   Shucked weight  4177 non-null   float64
#  5   Viscera weight  4177 non-null   float64
#  6   Shell weight    4177 non-null   float64
#  7   Rings           4177 non-null   int64
# dtypes: float64(7), int64(1)
# memory usage: 261.2 KB

# %%
#min-max scaling 권장하지 않는 방식.
data2 = (data - np.min(data)) / (np.max(data) - np.min(data))
data2 #min-max가 맞춰진다.
# Out:
#         Length  Diameter    Height  Whole weight  Shucked weight  \
# 0     0.513514  0.521008  0.084071      0.181335        0.150303
# 1     0.371622  0.352941  0.079646      0.079157        0.066241
# 2     0.614865  0.613445  0.119469      0.239065        0.171822
# 3     0.493243  0.521008  0.110619      0.182044        0.144250
# 4     0.344595  0.336134  0.070796      0.071897        0.059516
# ...        ...       ...       ...           ...             ...
# 4172  0.662162  0.663866  0.146018      0.313441        0.248151
# 4173  0.695946  0.647059  0.119469      0.341420        0.294553
# 4174  0.709459  0.705882  0.181416      0.415796        0.352724
# 4175  0.743243  0.722689  0.132743      0.386931        0.356422
# 4176  0.858108  0.840336  0.172566      0.689393        0.635171
#
#       Viscera weight  Shell weight     Rings
# 0           0.132324      0.147982  0.500000
# 1           0.063199      0.068261  0.214286
# 2           0.185648      0.207773  0.285714
# ...

# %%
# 1) 데이터 전처리 모듈의 불러오기 및 정의하기.
from sklearn.preprocessing import MinMaxScaler
mMscaler = MinMaxScaler()
mMscaler.fit(data) #fit으로 데이터 입히기.
data3 = mMscaler.transform(data) #변환작업
type(data3) #넘파이 array 타입. head는 pandas 타입.
data3
# Out:
# array([[0.51351351, 0.5210084 , 0.0840708 , ..., 0.1323239 , 0.14798206,
#         0.5       ],
#        [0.37162162, 0.35294118, 0.07964602, ..., 0.06319947, 0.06826109,
#         0.21428571],
#        [0.61486486, 0.61344538, 0.11946903, ..., 0.18564845, 0.2077728 ,
#         0.28571429],
#        ...,
#        [0.70945946, 0.70588235, 0.18141593, ..., 0.37788018, 0.30543099,
#         0.28571429],
#        [0.74324324, 0.72268908, 0.13274336, ..., 0.34298881, 0.29347285,
#         0.32142857],
#        [0.85810811, 0.84033613, 0.17256637, ..., 0.49506254, 0.49177877,
#         0.39285714]])

# %%
#편한 방법
mMscaler = MinMaxScaler()
data4 = mMscaler.fit_transform(data) #fit + transform 함수.
type(data4) #numpy 배열
mMscaled_data = pd.DataFrame(data4, columns = data.columns) #괄호 안은 numpy 배열, 칼럼 이름
mMscaled_data.head()
# Out:
#      Length  Diameter    Height  Whole weight  Shucked weight  Viscera weight  \
# 0  0.513514  0.521008  0.084071      0.181335        0.150303        0.132324
# 1  0.371622  0.352941  0.079646      0.079157        0.066241        0.063199
# 2  0.614865  0.613445  0.119469      0.239065        0.171822        0.185648
# 3  0.493243  0.521008  0.110619      0.182044        0.144250        0.149440
# 4  0.344595  0.336134  0.070796      0.071897        0.059516        0.051350
#
#    Shell weight     Rings
# 0      0.147982  0.500000
# 1      0.068261  0.214286
# 2      0.207773  0.285714
# 3      0.152965  0.321429
# 4      0.053313  0.214286

# %%
#2) Standard Scaling, data의 mean이 0, std를 1이 되도록 스케일링. 0, -1 , 1 사이에 배치시키는 것. 
# 평균은 0, 가장 높은 값이 1, 가장 낮은 값이 -1
from sklearn.preprocessing import StandardScaler
sdscaler = StandardScaler()
sdscaled_data = sdscaler.fit_transform(data) #numpy배열로 변환.
sdscaled_data = pd.DataFrame(sdscaled_data, columns = data.columns)
sdscaled_data.head() #-1이 넘는 값이 보임.
# Out:
#      Length  Diameter    Height  Whole weight  Shucked weight  Viscera weight  \
# 0 -0.574558 -0.432149 -1.064424     -0.641898       -0.607685       -0.726212
# 1 -1.448986 -1.439929 -1.183978     -1.230277       -1.170910       -1.205221
# 2  0.050033  0.122130 -0.107991     -0.309469       -0.463500       -0.356690
# 3 -0.699476 -0.432149 -0.347099     -0.637819       -0.648238       -0.607600
# 4 -1.615544 -1.540707 -1.423087     -1.272086       -1.215968       -1.287337
#
#    Shell weight     Rings
# 0     -0.638217  1.571544
# 1     -1.212987 -0.910013
# 2     -0.207139 -0.289624
# 3     -0.602294  0.020571
# 4     -1.320757 -0.910013

# %%
#3) Sampling / Oversampling, Undersampling
# 분류가 목적이며, 데이터 셋의 클래스 갯수가 한 쪽으로 치우쳐있을 때 맞춰주는 작업.
# 적은 클래스의 데이터 수를 증가 - Oversampling
# 많은 클래스의 데이터 수를 감소 - Undersampling
# Random Over / Under Sampling

from imblearn.over_sampling import RandomOverSampler
from imblearn.under_sampling import RandomUnderSampler
ros = RandomOverSampler()
rus = RandomUnderSampler()

# %%
#OverSampling
oversampled_data, oversampled_label = ros.fit_resample(data, label)
oversampled_data = pd.DataFrame(oversampled_data, columns = data.columns)
#UnderSampling
undersampled_data, undersampled_label = rus.fit_resample(data, label)
undersampled_data = pd.DataFrame(undersampled_data, columns = data.columns)

# %%
print('원본 데이터의 클래스 비율 \n{0}'.format(pd.get_dummies(label).sum()))
#label 데이터(원본 데이터의 성별만 따로 저장한 것.) get dummies + sum은 원본 데이터의 합계를 보여준다.
print('\nRandom Over Sampling 결과 \n{0}'.format(pd.get_dummies(oversampled_label).sum()))
#남자 성별의 클래스가 많으니 M쪽으로 숫자를 맞춰준다.
print('\nRandom Under Sampling 결과 \n{0}'.format(pd.get_dummies(undersampled_label).sum()))
# Out:
# 원본 데이터의 클래스 비율
# F    1307
# I    1342
# M    1528
# dtype: int64
#
# Random Over Sampling 결과
# F    1528
# I    1528
# M    1528
# dtype: int64
#
# Random Under Sampling 결과
# F    1307
# I    1307
# M    1307
# dtype: int64

# %%
#SMOTE 

from imblearn.over_sampling import SMOTE
smote = SMOTE(k_neighbors = 5)

# %%
from sklearn.datasets import make_classification
data, label = make_classification(n_samples = 1000,
                                  n_features = 2,
                                  n_informative = 2,
                                  n_redundant = 0,
                                  n_repeated = 0,
                                  n_classes = 3,
                                  n_clusters_per_class = 1,
                                  weights = [0.05,0.15,0.8],
                                  class_sep = 0.8,
                                  random_state = 2019)

# %%
#점찍기
fig = plt.Figure(figsize = (12,6))
plt.scatter(data[:,0], data[:,1], c = label, linewidth = 1, edgecolor = 'black')

# %%
smoted_data, smoted_label = smote.fit_resample(data, label)

# %%
print('원본 데이터의 클래스 비율\n{0}'.format(pd.get_dummies(label).sum()))
print('Smoted 데이터의 클래스 비율\n{0}'.format(pd.get_dummies(smoted_label).sum())) #oversampling data
# Out:
# 원본 데이터의 클래스 비율
# 0     53
# 1    154
# 2    793
# dtype: int64
# Smoted 데이터의 클래스 비율
# 0    793
# 1    793
# 2    793
# dtype: int64

# %%
fig = plt.Figure(figsize = (12,6))
plt.scatter(smoted_data[:,0], smoted_data[:,1],c = smoted_label, linewidth = 1, edgecolor = 'black')
#빈 자리를 이어나가는 듯한 그림

# %%
#dimension reduction
from sklearn.datasets import load_digits #사이킷런 내부의 데이터셋 불러오기.
digits = load_digits()

# %%
print(digits.DESCR) #DESCRIPTION 명령어.
# Out:
# .. _digits_dataset:
#
# Optical recognition of handwritten digits dataset
# --------------------------------------------------
#
# **Data Set Characteristics:**
#
#     :Number of Instances: 1797
#     :Number of Attributes: 64
#     :Attribute Information: 8x8 image of integer pixels in the range 0..16.
#     :Missing Attribute Values: None
#     :Creator: E. Alpaydin (alpaydin '@' boun.edu.tr)
#     :Date: July; 1998
#
# This is a copy of the test set of the UCI ML hand-written digits datasets
# https://archive.ics.uci.edu/ml/datasets/Optical+Recognition+of+Handwritten+Digits
#
# The data set contains images of hand-written digits: 10 classes where
# each class refers to a digit.
#
# Preprocessing programs made available by NIST were used to extract
# normalized bitmaps of handwritten digits from a preprinted form. From a
# total of 43 people, 30 contributed to the training set and different 13
# to the test set. 32x32 bitmaps are divided into nonoverlapping blocks of
# ...

# %%
data = digits.data
label = digits.target #scikit learn에서는 label이 타겟.

# %%
print(data[0])
print(label[0])
# Out:
# [ 0.  0.  5. 13.  9.  1.  0.  0.  0.  0. 13. 15. 10. 15.  5.  0.  0.  3.
#  15.  2.  0. 11.  8.  0.  0.  4. 12.  0.  0.  8.  8.  0.  0.  5.  8.  0.
#   0.  9.  8.  0.  0.  4. 11.  0.  1. 12.  7.  0.  0.  2. 14.  5. 10. 12.
#   0.  0.  0.  0.  6. 13. 10.  0.  0.  0.]
# 0

# %%
#데이터의 구조 바꿔주는 reshape()
#넘파이의 장점. 배열이나 길이를 자유롭게 바꿀 수 있음.
data[0].reshape(8,8)
#(8,-1)로 지정하면 데이터를 8개씩 끊고 갯수는 알아서 지정하라는 뜻.
# Out:
# array([[ 0.,  0.,  5., 13.,  9.,  1.,  0.,  0.],
#        [ 0.,  0., 13., 15., 10., 15.,  5.,  0.],
#        [ 0.,  3., 15.,  2.,  0., 11.,  8.,  0.],
#        [ 0.,  4., 12.,  0.,  0.,  8.,  8.,  0.],
#        [ 0.,  5.,  8.,  0.,  0.,  9.,  8.,  0.],
#        [ 0.,  4., 11.,  0.,  1., 12.,  7.,  0.],
#        [ 0.,  2., 14.,  5., 10., 12.,  0.,  0.],
#        [ 0.,  0.,  6., 13., 10.,  0.,  0.,  0.]])

# %%
plt.imshow(data[0].reshape(8,8))
print('Label : {}'.format(label[0]))
# Out:
# Label : 0

# %%
from sklearn.decomposition import PCA
pca = PCA(n_components = 2) #64차원 데이터를 2차원으로 줄여보기.

# %%
#데이터에서 주성분을 찾기.
new_data = pca.fit_transform(data)

# %%
#결과
print('원본 데이터의 차원 \n{}'.format(data.shape))
print('PCA 데이터의 차원 \n{}'.format(new_data.shape))
# Out:
# 원본 데이터의 차원
# (1797, 64)
# PCA 데이터의 차원
# (1797, 2)

# %%
plt.scatter(new_data[:,0], new_data[:,1], c = label, linewidth = 1, edgecolor = 'black')

# %%
# Label Encoding
data = pd.read_csv(abalone_path, header = None, names = abalone_columns)
label = data['Sex']
del data

# %%
from sklearn.preprocessing import LabelEncoder
labelEncode = LabelEncoder()
encoded_label = labelEncode.fit_transform(label)
encoded_label
# Out:
# array([2, 2, 0, ..., 2, 0, 2])

# %%
# One-hot Encoding, 데이터의 변별력 올려줌.
from sklearn.preprocessing import OneHotEncoder
ohe = OneHotEncoder(sparse = False)
ohe.fit(label.values.reshape((-1,1)))
one_hot_encoded = ohe.transform(label.values.reshape((-1,1)))
columns = np.concatenate([np.array(['label']), ohe.categories_[0]])
print(columns)

result = pd.DataFrame(data = np.concatenate(
                     [label.values.reshape((-1,1)), one_hot_encoded.reshape((-1,3))],
                      axis = 1), columns = columns)
result.head(10)
# Out:
# ['label' 'F' 'I' 'M']
#   label    F    I    M
# 0     M  0.0  0.0  1.0
# 1     M  0.0  0.0  1.0
# 2     F  1.0  0.0  0.0
# 3     M  0.0  0.0  1.0
# 4     I  0.0  1.0  0.0
# 5     I  0.0  1.0  0.0
# 6     F  1.0  0.0  0.0
# 7     F  1.0  0.0  0.0
# 8     M  0.0  0.0  1.0
# 9     F  1.0  0.0  0.0

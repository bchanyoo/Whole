# %%
import numpy as np
import matplotlib.pyplot as plt

# data 생성

data = np.concatenate([np.random.normal(0, 1, 900),
                       np.random.normal(8, 2, 100),
                       np.random.normal(-4, 2, 100)])
print(data)
# Out:
# [ 1.79899992  0.49025305 -2.11725051 ... -5.91634005 -5.59449037
#  -4.23945638]

# %%
# 상자 그림 시각화

fig, ax = plt.subplots()
ax.boxplot(data)
ax.set_xlabel('Data')
ax.set_ylabel('Values')
ax.set_title('Box Plot')
plt.show()

#대칭이 안 맞거나 박스가 크거나 한 쪽에 치우친 경우 좋지 않은 분포이다. (극단값이 많다)

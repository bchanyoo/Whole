# %%
import numpy as np
import matplotlib.pyplot as plt

# data 생성
data = np.random.normal(loc = 0, scale = 1, size = 10000)
print(data)
# Out:
# [ 0.11875583 -2.24914585  2.24753328 ... -0.76936544 -0.20538087
#  -0.12144154]

# %%
# 중심 경향성 계산하기
mean = np.mean(data) #평균
median = np.median(data) #중앙값
mode = np.round(np.mean(data)) #최빈값, round는 반올림.

print(mean, median, mode)
# Out:
# -0.0042187199046849685 -0.005225130113554119 -0.0

# %%
# 분포의 시각화
fig, ax = plt.subplots()
ax.hist(data, bins = 50)
ax.axvline(mean, color = 'red', linestyle = 'dashed', linewidth = 2)
ax.axvline(median, color = 'green', linestyle = 'dashed', linewidth = 2)
ax.axvline(mode, color = 'purple', linestyle = 'dashed', linewidth = 2)
ax.legend(['Mean: {:.2f}'.format(mean), 'Median: {:.2f}'.format(median), 'Mode: {:.2f}'.format(mode)])
ax.set_xlabel('Data Values')
ax.set_ylabel('Frequency')
ax.set_title('Data Distribution')
plt.show()
